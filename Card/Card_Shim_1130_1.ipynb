# %% [markdown]
# # 1. 문제정의

# %% [markdown]
#   ## 1.1 경진대회 소개
#
# - 데이콘 신용카드 사용자 연체 예측 AI 경진 대회
#
# - https://dacon.io/competitions/official/235713/overview/description
#
#     ### 1.1.1 평가
#   - 평가산식 : Logloss
#   - Public 평가 : 테스트 데이터 중 랜덤 샘플 된 50%로 채점
#   - Private 평가 : 나머지 50 % 테스트 데이터로 채점
#
#     ### 1.1.2 배경
#     - 신용카드사는 신용카드 신청자가 제출한 개인정보와 데이터를 활용해 신용 점수를 산정합니다. 신용카드사는 이 신용 점수를 활용해 신청자의 향후 채무 불이행과 신용카드 대급 연체 가능성을 예측합니다.
#
#     - 현재 많은 금융업계는 인공지능(AI)를 활용한 금융 서비스를 구현하고자 합니다. 사용자의 대금 연체 정도를 예측할 수 있는 인공지능 알고리즘을 개발해 금융업계에 제안할 수 있는 인사이트를 발굴해주세요!
#
#     ### 1.1.3 데이터 분석 대상
#     - train : 총 26,457행의 데이터 20열
#     - test : 총 10,000행의 데이터 19열("credit" 제외)
#
#     => train 데이터를 이용해 모델을 학습 시킨 뒤 test 데이터를 활용해 **"credit"** 예측

# %% [markdown]
# ## 1.2 데이터 도메인 정보
# -	index
# -	gender: 성별
# -	car: 차량 소유 여부
# -	reality: 부동산 소유 여부
# -	child_num: 자녀 수
# -	income_total: 연간 소득
# -	income_type: 소득 분류 ['Commercial associate', 'Working', 'State servant', 'Pensioner', 'Student']
# -	edu_type: 교육 수준 ['Higher education' ,'Secondary / secondary special', 'Incomplete higher', 'Lower secondary', 'Academic degree']
# -	family_type: 결혼 여부 ['Married', 'Civil marriage', 'Separated', 'Single / not married', 'Widow']
# -	house_type: 생활 방식 ['Municipal apartment', 'House / apartment', 'With parents', 'Co-op apartment', 'Rented apartment', 'Office apartment']
# -	DAYS_BIRTH: 출생일 데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 하루 전에 태어났음을 의미
# -	DAYS_EMPLOYED: 업무 시작일 데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 하루 전부터 일을 시작함을 의미 양수 값은 고용되지 않은 상태를 의미함
# -	FLAG_MOBIL: 핸드폰 소유 여부
# -	work_phone: 업무용 전화 소유 여부
# -	phone: 가정용 전화 소유 여부
# -	email: 이메일 소유 여부
# -	occyp_type: 직업 유형
# -	family_size: 가족 규모
# -	begin_month: 신용카드 발급 월 데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 한 달 전에 신용카드를 발급함을 의미
# -	credit: 사용자의 신용카드 대금 연체를 기준의 신용도 => 낮을 수록 높은 신용의 신용카드 사용자를 의미함

# %% [markdown]
# ## 1.3 평가척도
# => 참가자가 최종적으로 제출한 결과물의 우열을 판단하는 척도
#
# - 본 대회에서는 logloss라는 평가척도를 적용합니다. 이 logloss 값은 분류모델에서 평가지표로 사용하는 지표 중 하나이며, 0에 가까울수록 정확하다는 뜻이고, 확률이 낮아질수록 logloss값은 급격하게 커진다.

# %% [markdown]
# ## 1.4 문제 해결을 위한 접근 방식
#
# - 이번에는 기존 방식과는 다르게
# - **데이터 모델링 -> 결과 확인 -> EDA -> 전처리 -> 모델링 성능 개선**

# %% [markdown]
# ## 1.5 섹션 아이디어
# - [11.30]
#   - 1) 이번에는 지난 번과 다르게 먼저 기초적인 모델링을 통해 예측 후 성능 개선을 위해 추가적인 부분을 수정

# %% [markdown]
# # 2. 데이터 간단히 탐색

# %% [markdown]
# ## 2.1 데이터 연결
# - 데이터 로드를 위한 url 연결

# %%
import requests
from io import StringIO

# %%
# 학습 데이터 로드
orig_url = 'https://drive.google.com/file/d/1Rku0YUinqkflwUAgaT66uD4W1nhVEll5/view?usp=sharing'
file_id = orig_url.split('/')[-2]
down_url = 'https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(down_url).text
train_url = StringIO(url)

# %%
# 테스트 데이터 로드
orig_url = 'https://drive.google.com/file/d/1UpAcGoRB5zOqzNFw9EYMUwjLcWgzahYM/view?usp=sharing'
file_id = orig_url.split('/')[-2]
down_url = 'https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(down_url).text
test_url = StringIO(url)

# %%
# 제출 데이터 로드
orig_url = 'https://drive.google.com/file/d/157dN3myXQ-sIXNKiWRAVTs4fvU5ZChEJ/view?usp=sharing'
file_id = orig_url.split('/')[-2]
down_url = 'https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(down_url).text
sub_url = StringIO(url)

# %% [markdown]
# ## 2.2 데이터 로드

# %% [markdown]
# ### 2.2.1 학습 데이터

# %%
import pandas as pd

# %%
# 학습 데이터 로드
X = pd.read_csv(train_url)

# %%
# 학습 데이터 기본 정보 파악
display(X.info())

display(X.head().T)

display(X.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
#  17  family_size    26457 non-null  float64
#  18  begin_month    26457 non-null  float64
#  19  credit         26457 non-null  float64
# dtypes: float64(4), int64(8), object(8)
# memory usage: 4.0+ MB
# None
#                                   0  ...                  4
# index                             0  ...                  4
# gender                            F  ...                  F
# car                               N  ...                  Y
# reality                           N  ...                  Y
# child_num                         0  ...                  0
# income_total                 202500  ...             157500
# income_type    Commercial associate  ...      State servant
# edu_type           Higher education  ...   Higher education
# family_type                 Married  ...            Married
# house_type      Municipal apartment  ...  House / apartment
# DAYS_BIRTH                   -13899  ...             -15037
# DAYS_EMPLOYED                 -4709  ...              -2105
# FLAG_MOBIL                        1  ...                  1
# work_phone                        0  ...                  0
# phone                             0  ...                  0
# email                             0  ...                  0
# occyp_type                      NaN  ...           Managers
# family_size                       2  ...                  2
# begin_month                      -6  ...                -26
# credit                            1  ...                  2
#
# [20 rows x 5 columns]
#               index     child_num  ...   begin_month        credit
# count  26457.000000  26457.000000  ...  26457.000000  26457.000000
# mean   13228.000000      0.428658  ...    -26.123294      1.519560
# std     7637.622372      0.747326  ...     16.559550      0.702283
# min        0.000000      0.000000  ...    -60.000000      0.000000
# 25%     6614.000000      0.000000  ...    -39.000000      1.000000
# 50%    13228.000000      0.000000  ...    -24.000000      2.000000
# 75%    19842.000000      1.000000  ...    -12.000000      2.000000
# max    26456.000000     19.000000  ...      0.000000      2.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# ### 2.2.2 테스트 데이터

# %%
# 테스트 데이터 로드
test = pd.read_csv(test_url)

# %%
# 테스트 데이터 기본 정보 파악
display(test.info())

display(test.head())

display(test.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          10000 non-null  int64
#  1   gender         10000 non-null  object
#  2   car            10000 non-null  object
#  3   reality        10000 non-null  object
#  4   child_num      10000 non-null  int64
#  5   income_total   10000 non-null  float64
#  6   income_type    10000 non-null  object
#  7   edu_type       10000 non-null  object
#  8   family_type    10000 non-null  object
#  9   house_type     10000 non-null  object
#  10  DAYS_BIRTH     10000 non-null  int64
#  11  DAYS_EMPLOYED  10000 non-null  int64
#  12  FLAG_MOBIL     10000 non-null  int64
#  13  work_phone     10000 non-null  int64
#  14  phone          10000 non-null  int64
#  15  email          10000 non-null  int64
#  16  occyp_type     6848 non-null   object
#  17  family_size    10000 non-null  float64
#  18  begin_month    10000 non-null  float64
# dtypes: float64(3), int64(8), object(8)
# memory usage: 1.4+ MB
# None
#    index gender car reality  ...  email  occyp_type family_size begin_month
# 0  26457      M   Y       N  ...      0         NaN         2.0       -60.0
# 1  26458      F   N       Y  ...      0  Core staff         2.0       -36.0
# 2  26459      F   N       Y  ...      0    Laborers         2.0       -40.0
# 3  26460      M   Y       N  ...      0     Drivers         2.0       -41.0
# 4  26461      F   Y       Y  ...      0    Managers         2.0        -8.0
#
# [5 rows x 19 columns]
#              index     child_num  ...   family_size   begin_month
# count  10000.00000  10000.000000  ...  10000.000000  10000.000000
# mean   31456.50000      0.434700  ...      2.202700    -26.272400
# std     2886.89568      0.729102  ...      0.898272     16.348557
# min    26457.00000      0.000000  ...      1.000000    -60.000000
# 25%    28956.75000      0.000000  ...      2.000000    -39.000000
# 50%    31456.50000      0.000000  ...      2.000000    -25.000000
# 75%    33956.25000      1.000000  ...      3.000000    -12.000000
# max    36456.00000      5.000000  ...      7.000000      0.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# ### 2.2.3 제출 데이터

# %%
# 테스트 데이터 로드
sub = pd.read_csv(sub_url)

# %%
# 테스트 데이터 기본 정보 파악
display(sub.info())

display(sub.head())

display(sub.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   10000 non-null  int64
#  1   0       10000 non-null  int64
#  2   1       10000 non-null  int64
#  3   2       10000 non-null  int64
# dtypes: int64(4)
# memory usage: 312.6 KB
# None
#    index  0  1  2
# 0  26457  0  0  0
# 1  26458  0  0  0
# 2  26459  0  0  0
# 3  26460  0  0  0
# 4  26461  0  0  0
#              index        0        1        2
# count  10000.00000  10000.0  10000.0  10000.0
# mean   31456.50000      0.0      0.0      0.0
# std     2886.89568      0.0      0.0      0.0
# min    26457.00000      0.0      0.0      0.0
# 25%    28956.75000      0.0      0.0      0.0
# 50%    31456.50000      0.0      0.0      0.0
# 75%    33956.25000      0.0      0.0      0.0
# max    36456.00000      0.0      0.0      0.0

# %% [markdown]
# ## 2.3 섹션 아이디어
#
# - [11.30]
#   - 1) sub 3가지 유형 별 예측확률 필요 모델 학습 후 predict_proba 필요
#   - 2) train, test 모두 occyp_type(직업열)에 결측값 존재 -> 직업 정의를 내릴수  없는 직업들일 경우라 생각 -> "Etc" 값으로 대치
#   - 3) index값은 키 값 -> 학습에서 제외 가능
#   - 4) 범주형 데이터를 가진 열이 많다. -> 라벨 인코딩, 원-핫 인코딩 필요
#   - 5) 정규화 -> "RandomForest"에서는 필요 없다. -> 우선 랜포로 진행

# %% [markdown]
# # 3. 데이터 전처리

# %%
today = "1130_1"

# %% [markdown]
# ## 3.1 결측치 처리

# %% [markdown]
# ### 3.1.1 occupy

# %%
# 결측값 확인
display(pd.DataFrame(X.isnull().sum(),columns = ["X"]))

display(pd.DataFrame(test.isnull().sum(),columns = ["test"]))
# Out:
#                   X
# index             0
# gender            0
# car               0
# reality           0
# child_num         0
# income_total      0
# income_type       0
# edu_type          0
# family_type       0
# house_type        0
# DAYS_BIRTH        0
# DAYS_EMPLOYED     0
# FLAG_MOBIL        0
# work_phone        0
# phone             0
# email             0
# occyp_type     8171
# family_size       0
# begin_month       0
# credit            0
#                test
# index             0
# gender            0
# car               0
# reality           0
# child_num         0
# income_total      0
# income_type       0
# edu_type          0
# family_type       0
# house_type        0
# DAYS_BIRTH        0
# DAYS_EMPLOYED     0
# FLAG_MOBIL        0
# work_phone        0
# phone             0
# email             0
# occyp_type     3152
# family_size       0
# begin_month       0

# %% [markdown]
# 약 30%의 결측 보인다.

# %%
# occyp_type 열에 있는 결측값 "Etc" 대치
X["occyp_type"] = X["occyp_type"].fillna("Etc")
test["occyp_type"] = test["occyp_type"].fillna("Etc")

# %%
# 결측값 확인
display(pd.DataFrame(X.isnull().sum(),columns = ["X"]))

display(pd.DataFrame(test.isnull().sum(),columns = ["test"]))
# Out:
#                X
# index          0
# gender         0
# car            0
# reality        0
# child_num      0
# income_total   0
# income_type    0
# edu_type       0
# family_type    0
# house_type     0
# DAYS_BIRTH     0
# DAYS_EMPLOYED  0
# FLAG_MOBIL     0
# work_phone     0
# phone          0
# email          0
# occyp_type     0
# family_size    0
# begin_month    0
# credit         0
#                test
# index             0
# gender            0
# car               0
# reality           0
# child_num         0
# income_total      0
# income_type       0
# edu_type          0
# family_type       0
# house_type        0
# DAYS_BIRTH        0
# DAYS_EMPLOYED     0
# FLAG_MOBIL        0
# work_phone        0
# phone             0
# email             0
# occyp_type        0
# family_size       0
# begin_month       0

# %% [markdown]
# ## 3.2 원-핫 인코딩

# %%
# 수치형 변수 추출
v_i = ["child_num","income_total","DAYS_BIRTH","DAYS_EMPLOYED",
       "family_size", "begin_month"]
tr_i = X[v_i]
tr_s = X.drop(v_i,axis=1)
tr_s = tr_s.drop(["index","credit"],axis = 1)
tr_s = tr_s.astype("object")
tr_t = X["credit"]

# %%
# 수치형 변수 추출
v_i = ["child_num","income_total","DAYS_BIRTH","DAYS_EMPLOYED",
       "family_size", "begin_month"]
te_i = test[v_i]
te_s = test.drop(v_i,axis=1) 
te_s = te_s.drop("index",axis = 1)
te_s = te_s.astype("object")

# %%
tr_dummy = pd.get_dummies(tr_s)
te_dummy = pd.get_dummies(te_s)
display(tr_dummy)
# Out:
#        gender_F  ...  occyp_type_Waiters/barmen staff
# 0             1  ...                                0
# 1             1  ...                                0
# 2             0  ...                                0
# 3             1  ...                                0
# 4             1  ...                                0
# ...         ...  ...                              ...
# 26452         1  ...                                0
# 26453         1  ...                                0
# 26454         1  ...                                0
# 26455         0  ...                                0
# 26456         1  ...                                0
#
# [26457 rows x 53 columns]

# %% [markdown]
# ## 3.3 정규화

# %% [markdown]
# ## 3.4 데이터 통합

# %%
#수치형 변수와 범주형 변수 데이터열 합성
new_X = pd.concat([tr_i,tr_dummy],axis= 1)
new_test = pd.concat([te_i,te_dummy],axis= 1)
y = tr_t
display(new_X.info())
display(new_test.info())
# display(tr_t)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 59 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   child_num                               26457 non-null  int64
#  1   income_total                            26457 non-null  float64
#  2   DAYS_BIRTH                              26457 non-null  int64
#  3   DAYS_EMPLOYED                           26457 non-null  int64
#  4   family_size                             26457 non-null  float64
#  5   begin_month                             26457 non-null  float64
#  6   gender_F                                26457 non-null  uint8
#  7   gender_M                                26457 non-null  uint8
#  8   car_N                                   26457 non-null  uint8
#  9   car_Y                                   26457 non-null  uint8
#  10  reality_N                               26457 non-null  uint8
#  11  reality_Y                               26457 non-null  uint8
#  12  income_type_Commercial associate        26457 non-null  uint8
#  13  income_type_Pensioner                   26457 non-null  uint8
#  14  income_type_State servant               26457 non-null  uint8
#  15  income_type_Student                     26457 non-null  uint8
#  16  income_type_Working                     26457 non-null  uint8
#  17  edu_type_Academic degree                26457 non-null  uint8
#  18  edu_type_Higher education               26457 non-null  uint8
#  19  edu_type_Incomplete higher              26457 non-null  uint8
#  20  edu_type_Lower secondary                26457 non-null  uint8
#  21  edu_type_Secondary / secondary special  26457 non-null  uint8
#  22  family_type_Civil marriage              26457 non-null  uint8
#  23  family_type_Married                     26457 non-null  uint8
#  24  family_type_Separated                   26457 non-null  uint8
#  25  family_type_Single / not married        26457 non-null  uint8
#  26  family_type_Widow                       26457 non-null  uint8
#  27  house_type_Co-op apartment              26457 non-null  uint8
#  28  house_type_House / apartment            26457 non-null  uint8
#  29  house_type_Municipal apartment          26457 non-null  uint8
#  30  house_type_Office apartment             26457 non-null  uint8
#  31  house_type_Rented apartment             26457 non-null  uint8
#  32  house_type_With parents                 26457 non-null  uint8
#  33  FLAG_MOBIL_1                            26457 non-null  uint8
#  34  work_phone_0                            26457 non-null  uint8
#  35  work_phone_1                            26457 non-null  uint8
#  36  phone_0                                 26457 non-null  uint8
#  37  phone_1                                 26457 non-null  uint8
#  38  email_0                                 26457 non-null  uint8
#  39  email_1                                 26457 non-null  uint8
#  40  occyp_type_Accountants                  26457 non-null  uint8
#  41  occyp_type_Cleaning staff               26457 non-null  uint8
#  42  occyp_type_Cooking staff                26457 non-null  uint8
#  43  occyp_type_Core staff                   26457 non-null  uint8
#  44  occyp_type_Drivers                      26457 non-null  uint8
#  45  occyp_type_Etc                          26457 non-null  uint8
#  46  occyp_type_HR staff                     26457 non-null  uint8
#  47  occyp_type_High skill tech staff        26457 non-null  uint8
#  48  occyp_type_IT staff                     26457 non-null  uint8
#  49  occyp_type_Laborers                     26457 non-null  uint8
#  50  occyp_type_Low-skill Laborers           26457 non-null  uint8
#  51  occyp_type_Managers                     26457 non-null  uint8
#  52  occyp_type_Medicine staff               26457 non-null  uint8
#  53  occyp_type_Private service staff        26457 non-null  uint8
#  54  occyp_type_Realty agents                26457 non-null  uint8
#  55  occyp_type_Sales staff                  26457 non-null  uint8
#  56  occyp_type_Secretaries                  26457 non-null  uint8
#  57  occyp_type_Security staff               26457 non-null  uint8
#  58  occyp_type_Waiters/barmen staff         26457 non-null  uint8
# dtypes: float64(3), int64(3), uint8(53)
# memory usage: 2.5 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 59 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   child_num                               10000 non-null  int64
#  1   income_total                            10000 non-null  float64
#  2   DAYS_BIRTH                              10000 non-null  int64
#  3   DAYS_EMPLOYED                           10000 non-null  int64
#  4   family_size                             10000 non-null  float64
#  5   begin_month                             10000 non-null  float64
#  6   gender_F                                10000 non-null  uint8
#  7   gender_M                                10000 non-null  uint8
#  8   car_N                                   10000 non-null  uint8
#  9   car_Y                                   10000 non-null  uint8
#  10  reality_N                               10000 non-null  uint8
#  11  reality_Y                               10000 non-null  uint8
#  12  income_type_Commercial associate        10000 non-null  uint8
#  13  income_type_Pensioner                   10000 non-null  uint8
#  14  income_type_State servant               10000 non-null  uint8
#  15  income_type_Student                     10000 non-null  uint8
#  16  income_type_Working                     10000 non-null  uint8
#  17  edu_type_Academic degree                10000 non-null  uint8
#  18  edu_type_Higher education               10000 non-null  uint8
#  19  edu_type_Incomplete higher              10000 non-null  uint8
#  20  edu_type_Lower secondary                10000 non-null  uint8
#  21  edu_type_Secondary / secondary special  10000 non-null  uint8
#  22  family_type_Civil marriage              10000 non-null  uint8
#  23  family_type_Married                     10000 non-null  uint8
#  24  family_type_Separated                   10000 non-null  uint8
#  25  family_type_Single / not married        10000 non-null  uint8
#  26  family_type_Widow                       10000 non-null  uint8
#  27  house_type_Co-op apartment              10000 non-null  uint8
#  28  house_type_House / apartment            10000 non-null  uint8
#  29  house_type_Municipal apartment          10000 non-null  uint8
#  30  house_type_Office apartment             10000 non-null  uint8
#  31  house_type_Rented apartment             10000 non-null  uint8
#  32  house_type_With parents                 10000 non-null  uint8
#  33  FLAG_MOBIL_1                            10000 non-null  uint8
#  34  work_phone_0                            10000 non-null  uint8
#  35  work_phone_1                            10000 non-null  uint8
#  36  phone_0                                 10000 non-null  uint8
#  37  phone_1                                 10000 non-null  uint8
#  38  email_0                                 10000 non-null  uint8
#  39  email_1                                 10000 non-null  uint8
#  40  occyp_type_Accountants                  10000 non-null  uint8
#  41  occyp_type_Cleaning staff               10000 non-null  uint8
#  42  occyp_type_Cooking staff                10000 non-null  uint8
#  43  occyp_type_Core staff                   10000 non-null  uint8
#  44  occyp_type_Drivers                      10000 non-null  uint8
#  45  occyp_type_Etc                          10000 non-null  uint8
#  46  occyp_type_HR staff                     10000 non-null  uint8
#  47  occyp_type_High skill tech staff        10000 non-null  uint8
#  48  occyp_type_IT staff                     10000 non-null  uint8
#  49  occyp_type_Laborers                     10000 non-null  uint8
#  50  occyp_type_Low-skill Laborers           10000 non-null  uint8
#  51  occyp_type_Managers                     10000 non-null  uint8
#  52  occyp_type_Medicine staff               10000 non-null  uint8
#  53  occyp_type_Private service staff        10000 non-null  uint8
#  54  occyp_type_Realty agents                10000 non-null  uint8
#  55  occyp_type_Sales staff                  10000 non-null  uint8
#  56  occyp_type_Secretaries                  10000 non-null  uint8
#  57  occyp_type_Security staff               10000 non-null  uint8
#  58  occyp_type_Waiters/barmen staff         10000 non-null  uint8
# dtypes: float64(3), int64(3), uint8(53)
# memory usage: 986.5 KB
# None

# %%
# 데이터 저장
new_X.to_csv("/content/drive/Shareddrives/A-2/심종수/Card/prepro/new_X_{}.csv".format(today),index = False, encoding = "cp949")
y.to_csv("/content/drive/Shareddrives/A-2/심종수/Card/prepro/y_{}.csv".format(today),index = False, encoding = "cp949")
new_test.to_csv("/content/drive/Shareddrives/A-2/심종수/Card/prepro/new_test_{}.csv".format(today),index = False, encoding = "cp949")

# %% [markdown]
# # 4. 데이터 분할

# %% [markdown]
# ## 4.1 데이터 분할

# %%
#앞에 저장한 데이터 로드

X = pd.read_csv("/content/drive/Shareddrives/A-2/심종수/Card/prepro/new_X_{}.csv".format(today))
y = pd.read_csv("/content/drive/Shareddrives/A-2/심종수/Card/prepro/y_{}.csv".format(today))
test = pd.read_csv("/content/drive/Shareddrives/A-2/심종수/Card/prepro/new_test_{}.csv".format(today))

# %%
# 데이터 분할
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state = 42, stratify = y)

# %% [markdown]
# ## 4.2 데이터 교차검증

# %% [markdown]
# # 5. 모델링

# %% [markdown]
# ## 5.1 모델선정

# %%
# # 랜덤포레스트
# from sklearn.ensemble import RandomForestClassifier

# model = RandomForestClassifier(random_state = 42)
# model.fit(X_train,y_train)
# model.score(X_train,y_train)

# %% [markdown]
# ## 5.2 최적의 하이퍼파라미터 설정

# %%
from sklearn.model_selection import GridSearchCV

# %%
para = {'max_depth' : [6, 10],
           'min_samples_leaf' : [8, 12],
           'min_samples_split' : [8, 16]}

# 랜덤포레스트 모델 생성
rf = RandomForestClassifier(random_state = 42)
#그리드 서치 모델
gs = GridSearchCV(rf, param_grid = para, cv = 3)
#그리드 서치하며 학습
gs.fit(X_train,y_train)
#최적의 모델 선정
gs_best = gs.best_estimator_

display(gs.best_score_)
display(gs.best_params_)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:681: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:926: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# 0.692420118939623
# {'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 8}

# %%
display(gs_best.score(X_train,y_train))
# Out:
# 0.6929744985384538

# %% [markdown]
# # 6. 모델 성능 평가

# %% [markdown]
# ## 6.1 logloss 평가 지표 확인

# %%
from sklearn.metrics import log_loss

pred_test = gs_best.predict_proba(X_test)

test_score = log_loss(y_test,pred_test)

display(test_score)
# Out:
# 0.8040989699544631

# %%
from sklearn.metrics import log_loss

pred_test = gs_best.predict_proba(X_test)

test_score = log_loss(y_test,pred_test)

display(test_score)
# Out:
# 0.8040989699544631

# %% [markdown]
# # 7. 예측 진행

# %% [markdown]
# ## 7.1 최종 모델 학습

# %%
# # 랜덤포레스트
# from sklearn.ensemble import RandomForestClassifier

# model_f = RandomForestClassifier(random_state = 42)
# model_f.fit(X,y)
# model_f.score(X_train,y_train)

# %% [markdown]
# ## 7.2 최종 예측

# %%
pred = gs_best.predict_proba(test)

sub.loc[:,1:4] = pred

display(sub)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       index         0         1         2
# 0     26457  0.106617  0.195608  0.697775
# 1     26458  0.118212  0.192228  0.689559
# 2     26459  0.117328  0.209243  0.673429
# 3     26460  0.125497  0.171118  0.703385
# 4     26461  0.124669  0.196290  0.679040
# ...     ...       ...       ...       ...
# 9995  36452  0.122807  0.211759  0.665434
# 9996  36453  0.132656  0.241556  0.625788
# 9997  36454  0.109388  0.168953  0.721659
# 9998  36455  0.117516  0.188253  0.694231
# 9999  36456  0.129055  0.235313  0.635632
#
# [10000 rows x 4 columns]

# %%
# 제출파일 생성
sub.to_csv("/content/drive/Shareddrives/A-2/심종수/Card/sub/sub_{}.csv".format(today),index=False, encoding= "cp949")

# %% [markdown]
# # 총 평
# - [1130]
#   - 1) 과적합되는 듯한 점수를 보여준다. (1차 시도 split 데이터 2차 시도 전체 데이터) -> 전체 데이터로 학습을 시킨다고 성능이 좋아지지 않는다.
#
# - [1130_1]
#   - 1) 그리드서치를 통해 최적의 모델 선정 진행
#   - 2) 'n_estimators', 'max_feature' 처음에는 이 두가지 파라미터로 설정하고 학습 진행 후 예측했지만 성능 개선효과가 없었다.
#   - 3) 'max_depth', 'min_samples_leaf', 'min_samples_split' 이 세가지 파라미터를 설정하고 학습 진행 후 예측 성능이 상당히 개선되었다.
